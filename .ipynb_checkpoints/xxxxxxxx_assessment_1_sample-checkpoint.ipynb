# %% [markdown]
# # FIT5196 Data Wrangling - S2 2016
#
# ## Assessment 1 - Exploring Raw Data
#
# Filename: XXXXXXXX_assessment_1.ipynb
#
# Author: XXXX XXXX
#
# Student ID: XXXXXXXX
#
# Date: 7-Aug-2016
#
# Version: 1.0
#
# Language: Python 2.7.12 and Jupyter notebook Anaconda 2
#
# Libraries used:
# - `pandas`: for data frames
# - `numpy`: for numpy arrays
# - `re`: for regular expressions
# - `datetime`: for datetime data types
#
# ## Introduction
#
# This code is developed to pre-process and inspect an existing data set (“data.dat”). It performs the following tasks:
#
# **Task 1: Examine and Load the Data -** Inspect and import the raw data file in to pandas Dataframe. Includes processing to fix records with attributes split across multiple columns.
#
# **Task 2: Parse the Data -** The following parsing steps are included:
# >Step 1: Check columns attributes are consistent
# >Step 2: Extract and Set the column names
# >Step 3: Check for an index column
# >Step 4: Set NaN values
# >Step 5: Set the "Start" and "End" Column Datatypes to Datetime
# >Step 6: Set the "Killed" and "Affected" Column Datatype to Integer
# >Step 7: Set the "Cost" Column Datatype to Float
#
# **Task 3: Save Data to CSV File -** Reformat the dataframe for output and save the data to the file "XXXXXXXX_parsed_data.csv"
#
# ## Resources Used
#
# - Online Python Documentation - https://docs.python.org/2/index.html
# - Online Pandas Documentation - http://pandas.pydata.org/pandas-docs/stable/index.html
# - Stack Overflow, in particular:
#  - Information about formatting floats for the to_csv method - http://stackoverflow.com/questions/20003290/print-different-precision-by-column-with-pandas-dataframe-to-csv
#  - Information about the Pandas map function - http://stackoverflow.com/questions/19798153/difference-between-map-applymap-and-apply-methods-in-pandas
#  - Information about Pandas integers and NaN values - http://stackoverflow.com/questions/11548005/numpy-or-pandas-keeping-array-type-as-integer-while-having-a-nan-value

# %%
# Import required libraries
import pandas as pd
import numpy as np
import re
import datetime as dt

# %% [markdown]
# ## Task 1: Examine and Load the Data

# %% [markdown]
# ### Examine the Data
#
# Read the first few lines of the file to determine the file format

# %%
dataFile = open("data.dat","r")                    # Open the file
dataLines = dataFile.readlines()                   # Read the file
for i in range(5):                                 # Print the first few lines ...
    print dataLines[i] 
print "---------"    
for i in range(len(dataLines)-5,len(dataLines)):   # ... and the last few
    print dataLines[i]          
dataFile.close()                                   # Close the file
# Out:
# Start = 10061965,End = 10061965,Country:Japan,Location : nan,Type:Storm,Sub_Type:Tropical cyclone,Names:Dinah,Killed = 61. 0,Affected = 30000.0,Cost = nan,ID = 1965-0036
#
# Start = 08092004,End = 08092004,Country:Grenada,Location : nan,Type:Storm,Sub_Type:Tropical cyclone,Names:Ivan,Killed = 39. 0,Affected = 60000.0,Cost = 889.0,ID = 2004-0462
#
# Start = 15031995,End = 15031995,Country:Russia,Location : Kalmoukie:Daghestan (Mer ...,Type:Transport Accident,Sub_Type:Water,Names:nan,Killed = 52. 0,Affected = nan,Cost = nan,ID = 1995-0362
#
# Start = 00021983,End = 00021983,Country:Cuba,Location : Santiago de Cuba:Pinar d ...,Type:Flood,Sub_Type:nan,Names:nan,Killed = 15. 0,Affected = 164575.0,Cost = 60.0,ID = 1983-0042
#
# Start = 00001983,End = 00001983,Country:Nepal,Location : nan,Type:Mass movement wet,Sub_Type:Landslide,Names:nan,Killed = 21. 0,Affected = nan,Cost = nan,ID = 1983-0526
#
# ---------
# Start = 09042000,End = 09042000,Country:Uganda,Location : Lake Albert,Type:Transport Accident,Sub_Type:Water,Names:nan,Killed = 41. 0,Affected = 11.0,Cost = nan,ID = 2000-0915
#
# Start = 19012007,End = 19012007,Country:Mozambique,Location : Angoche (Nampula province ...,Type:Transport Accident,Sub_Type:Road,Names:nan,Killed = 17. 0,Affected = 19.0,Cost = nan,ID = 2007-0018
#
# Start = 09042006,End = 25042006,Country:Ethiopia,Location : Eastern Afar:Eastern Som ...,Type:Flood,Sub_Type:General flood,Names:nan,Killed = nan,Affected = 10000.0,Cost = nan,ID = 2006-0204
#
# Start = 11122006,End = 11122006,Country:China,Location : Lingshi (Shanxi province) ...,Type:Industrial Accident,Sub_Type:Explosion,Names:Coal mine,Killed = 26. 0,Affected = nan,Cost = nan,ID = 2006-0591
#
# Start = 13071998,End = 13071998,Country:Iran Islam Rep,Location : Mashad,Type:Transport Accident,Sub_Type:Road,Names:nan,Killed = 25. 0,Affected = 4.0,Cost = nan,ID = 1998-0523

# %% [markdown]
# The data has these characteristics:
# - There is no header record
# - The fields are comma-separated
# - Attribute names are embedded in the data
# - There are no trailing records

# %% [markdown]
# ### Read the Data into a Pandas Dataframe
#
# The data file has comma-separated fields, so process as a csv file with no header record.
#
# Most records have 11 fields, but a few records have one or two extra commas, so 13 columns are needed to store the data. By default the number of columns is inferred from the first record, so explicit column names are provided to ensure the dataframe has the correct number of columns.

# %%
data = pd.read_csv("data.dat",              # File is in CSV format
                   header=None,             # File does not have a header record
                   error_bad_lines=False,   # Do not raise an error if bad records are found
                   warn_bad_lines=True,     # Generate warnings for any bad records
                   names=["col1","col2","col3","col4","col5","col6","col7","col8","col9","col10","col11","col12","col13"])

# %%
# have a look at the first few records
data.head()
# Out:
#                col1            col2             col3  \
# 0  Start = 10061965  End = 10061965    Country:Japan
# 1  Start = 08092004  End = 08092004  Country:Grenada
# 2  Start = 15031995  End = 15031995   Country:Russia
# 3  Start = 00021983  End = 00021983     Country:Cuba
# 4  Start = 00001983  End = 00001983    Country:Nepal
#
#                                       col4                     col5  \
# 0                           Location : nan               Type:Storm
# 1                           Location : nan               Type:Storm
# 2  Location : Kalmoukie:Daghestan (Mer ...  Type:Transport Accident
# 3  Location : Santiago de Cuba:Pinar d ...               Type:Flood
# 4                           Location : nan   Type:Mass movement wet
#
#                         col6         col7            col8  \
# 0  Sub_Type:Tropical cyclone  Names:Dinah  Killed = 61. 0
# 1  Sub_Type:Tropical cyclone   Names:Ivan  Killed = 39. 0
# 2             Sub_Type:Water    Names:nan  Killed = 52. 0
# 3               Sub_Type:nan    Names:nan  Killed = 15. 0
# 4         Sub_Type:Landslide    Names:nan  Killed = 21. 0
#
#                   col9         col10           col11 col12 col13
# 0   Affected = 30000.0    Cost = nan  ID = 1965-0036   NaN   NaN
# 1   Affected = 60000.0  Cost = 889.0  ID = 2004-0462   NaN   NaN
# 2       Affected = nan    Cost = nan  ID = 1995-0362   NaN   NaN
# 3  Affected = 164575.0   Cost = 60.0  ID = 1983-0042   NaN   NaN
# 4       Affected = nan    Cost = nan  ID = 1983-0526   NaN   NaN

# %% [markdown]
# ### Fix records with extra columns
#
# **Check the records with more than 11 columns**

# %%
# find the records with extra columns
data[pd.notnull(data["col12"])]
# Out:
#                    col1            col2                     col3  \
# 1279   Start = 00012008  End = 00072008     Country:Burkina Faso
# 2152   Start = 19072003  End = 21072003            Country:Japan
# 2402   Start = 00081974  End = 00081974  Country:Germany Fed Rep
# 3214   Start = 27051989  End = 27051989   Country:Iran Islam Rep
# 4890   Start = 01091923  End = 01091923            Country:Japan
# 5675   Start = 07031999  End = 13031999   Country:United Kingdom
# 5691   Start = 07271976  End = 07271976            Country:China
# 5959   Start = 01032008  End = 14032008        Country:Indonesia
# 6222   Start = 00061988  End = 00061988         Country:Ethiopia
# 6388   Start = 07031999  End = 10041999          Country:Belarus
# 6535   Start = 19041989  End = 19041989    Country:United States
# 6905   Start = 00021979  End = 00021979        Country:Australia
# 7699   Start = 14081989  End = 14081989       Country:Bangladesh
# 7951   Start = 20032004  End = 20032004          Country:Nigeria
# 9139   Start = 19122001  End = 22122001     Country:South Africa
# 9376   Start = 02082005  End = 04082005        Country:Korea Rep
# 10646  Start = 12111909  End = 12111909            Country:Haiti
# 11350  Start = 08101997  End = 08101997            Country:Japan
# 11658  Start = 25051992  End = 25051992             Country:Cuba
# 12180  Start = 17121997  End = 17121997           Country:Russia
# 12353  Start = 09121970  End = 09121970             Country:Peru
# 14121  Start = 06001988  End = 00001988            Country:China
#
#                                     col4                     col5  \
# 1279                   Location : Sapouy     Gaoua:Mangodar:B ...
# 2152                 Location : Minamata      Hishikari:Kinka ...
# 2402             Location : Lower Saxony                  Bavaria
# 3214                     Location : Fars  Yasuj:Kohkiluyeh-Bo ...
# 4890   Location : Kanto plaine (Yokohama                   To ...
# 5675                   Location : Malton    Old Malton:Norton ...
# 5691            Location : Tangshan:Pek.                 Tientsin
# 5959           Location : Lamongan:Ngawi            Bojonego  ...
# 6222                   Location : Tigray                  Eritrea
# 6388                    Location : Brest  Gomel and Minsk reg ...
# 6535          Location : Atlantique ocea                      NaN
# 6905            Location : Act:Gouldburn            Yass:Mitt ...
# 7699                   Location : Sylhet    Bandarban:Cox's B ...
# 7951               Location : Between Sa       go and Ifo (Og ...
# 9139          Location : Greater Tubatse            Thembisil ...
# 9376             Location : North Jeolla         South Jeolla ...
# 10646              Location : Cul de Sac                  Leogane
# 11350                   Location : Tokyo                 Yokohama
# 11658                  Location : Granma    Santiago de Cuba: ...
# 12180               Location : Bashkiria                 Orenburg
# 12353                   Location : Piura                   Tumbes
# 14121                   Location : Hubei    Jiangsu:Henan:Anh ...
#
#                                      col6  \
# 1279                        Type:Epidemic
# 2152                           Type:Flood
# 2402                           Type:Storm
# 3214   Type:Earthquake (seismic activity)
# 4890   Type:Earthquake (seismic activity)
# 5675                           Type:Flood
# 5691   Type:Earthquake (seismic activity)
# 5959                           Type:Flood
# 6222              Type:Insect infestation
# 6388                           Type:Flood
# 6535              Type:Transport Accident
# 6905                        Type:Wildfire
# 7699                           Type:Flood
# 7951              Type:Transport Accident
# 9139                           Type:Flood
# 9376                           Type:Flood
# 10646                          Type:Storm
# 11350                      Nagoya (ci ...
# 11658  Type:Earthquake (seismic activity)
# 12180                       Type:Epidemic
# 12353  Type:Earthquake (seismic activity)
# 14121                        Type:Drought
#
#                                          col7  \
# 1279   Sub_Type:Bacterial Infectious Diseases
# 2152                   Sub_Type:General flood
# 2402                             Sub_Type:nan
# 3214     Sub_Type:Earthquake (ground shaking)
# 4890     Sub_Type:Earthquake (ground shaking)
# 5675                   Sub_Type:General flood
# 5691     Sub_Type:Earthquake (ground shaking)
# 5959                   Sub_Type:General Flood
# 6222                          Sub_Type:Locust
# 6388                   Sub_Type:General flood
# 6535                           Sub_Type:Water
# 6905            Sub_Type:Scrub/grassland fire
# 7699                   Sub_Type:General flood
# 7951                            Sub_Type:Road
# 9139                     Sub_Type:Flash flood
# 9376                     Sub_Type:Flash flood
# 10646               Sub_Type:Tropical cyclone
# 11350                           Type:Epidemic
# 11658    Sub_Type:Earthquake (ground shaking)
# 12180      Sub_Type:Viral Infectious Diseases
# 12353    Sub_Type:Earthquake (ground shaking)
# 14121                        Sub_Type:Drought
#
#                                                col8                 col9  \
# 1279                               Names:Meningitis      Killed = 250. 0
# 2152                                      Names:nan       Killed = 23. 0
# 2402                                      Names:nan         Killed = nan
# 3214                                      Names:nan      Killed = 100. 0
# 4890                                      Names:nan   Killed = 143000. 0
# 5675                                      Names:nan         Killed = nan
# 5691                                      Names:nan   Killed = 242000. 0
# 5959                                      Names:nan        Killed = 3. 0
# 6222                        Names:Locusts:armyworms         Killed = nan
# 6388                                      Names:nan        Killed = 2. 0
# 6535                              Names:Boat 'Iowa'       Killed = 47. 0
# 6905                                      Names:nan         Killed = nan
# 7699                                      Names:nan      Killed = 180. 0
# 7951                                      Names:nan       Killed = 25. 0
# 9139                                      Names:nan        Killed = 5. 0
# 9376                                      Names:nan       Killed = 18. 0
# 10646                                     Names:nan      Killed = 150. 0
# 11350        Sub_Type:Bacterial Infectious Diseases  Names:Campylobacter
# 11658                                     Names:nan         Killed = nan
# 12180  Names:Haemorrhagic fever with renal syndrome         Killed = nan
# 12353                                     Names:nan       Killed = 29. 0
# 14121                                     Names:nan     Killed = 1400. 0
#
#                        col10             col11           col12           col13
# 1279       Affected = 2000.0        Cost = nan  ID = 2008-0076             NaN
# 2152        Affected = 814.0        Cost = 7.0  ID = 2003-0343             NaN
# 2402          Affected = nan       Cost = 22.0  ID = 1974-0043             NaN
# 3214        Affected = 217.0        Cost = nan  ID = 1989-0090             NaN
# 4890     Affected = 203733.0      Cost = 600.0  ID = 1923-0006             NaN
# 5675        Affected = 330.0      Cost = 32.68  ID = 1999-0091             NaN
# 5691     Affected = 164000.0     Cost = 5600.0  ID = 1976-0050             NaN
# 5959      Affected = 12000.0        Cost = nan  ID = 2008-0108             NaN
# 6222          Affected = nan        Cost = nan  ID = 1988-0243             NaN
# 6388       Affected = 2000.0       Cost = 4.38  ID = 1999-0132             NaN
# 6535          Affected = nan        Cost = nan  ID = 1989-0489             NaN
# 6905          Affected = nan       Cost = 4.09  ID = 1979-0241             NaN
# 7699     Affected = 200000.0        Cost = nan  ID = 1989-0119             NaN
# 7951          Affected = 6.0        Cost = nan  ID = 2004-0118             NaN
# 9139        Affected = 312.0        Cost = nan  ID = 2001-0664             NaN
# 9376      Affected = 14510.0        Cost = nan  ID = 2005-0392             NaN
# 10646         Affected = nan        Cost = nan  ID = 1909-0012             NaN
# 11350           Killed = nan  Affected = 460.0      Cost = nan  ID = 1997-0500
# 11658      Affected = 5869.0        Cost = nan  ID = 1992-0067             NaN
# 12180      Affected = 4538.0        Cost = nan  ID = 1997-0510             NaN
# 12353     Affected = 15252.0        Cost = 2.0  ID = 1970-0068             NaN
# 14121  Affected = 49000000.0    Cost = 942.887  ID = 1988-9237             NaN

# %% [markdown]
# All the records with extra columns have multiple locations that were separated by commas instead of colons

# %% [markdown]
# **Fix the record with 13 columns**

# %%
# Fix the record with 13 fields by merging col5 and col6 with col4
idx = pd.notnull(data["col13"])
data.loc[idx,"col4"] = data.loc[idx,"col4"].str.cat([data.loc[idx,"col5"], data.loc[idx,"col6"]], sep=",")

# Shift columns 7-13 two to the left
for i in range(5,12):
    data.loc[idx, "col"+str(i)] = data.loc[idx, "col"+str(i+2)]

# Set the redundant columns to null    
for i in range(12,14):
    data.loc[idx, "col"+str(i)] = np.nan

# %%
data.loc[idx]
# Out:
#                    col1            col2           col3  \
# 11350  Start = 08101997  End = 08101997  Country:Japan
#
#                                            col4           col5  \
# 11350  Location : Tokyo,Yokohama,Nagoya (ci ...  Type:Epidemic
#
#                                          col6                 col7  \
# 11350  Sub_Type:Bacterial Infectious Diseases  Names:Campylobacter
#
#                col8              col9       col10           col11 col12 col13
# 11350  Killed = nan  Affected = 460.0  Cost = nan  ID = 1997-0500   NaN   NaN

# %% [markdown]
# **Fix the records with 12 columns**

# %%
# Get list of records with a col12 value (and a col5 value as no need to merge if col5 is NULL)
idx = (pd.notnull(data["col12"]) & pd.notnull(data["col5"])).tolist()

# Fix the records with 12 fields by merging col5 with col4
data.loc[idx,"col4"] = data.loc[idx,"col4"].str.cat(data.loc[idx,"col5"], sep=",")

# Regenerate the list for shift operation - include record with NULL in col5
idx = pd.notnull(data["col12"]).tolist()

# Shift columns 6-12 to the left
for i in range(5,12):
    data.loc[idx, "col"+str(i)] = data.loc[idx, "col"+str(i+1)]

# Set the redundant column to null   
data.loc[idx, "col12"] = np.nan

# %%
data.loc[idx]
# Out:
#                    col1            col2                     col3  \
# 1279   Start = 00012008  End = 00072008     Country:Burkina Faso
# 2152   Start = 19072003  End = 21072003            Country:Japan
# 2402   Start = 00081974  End = 00081974  Country:Germany Fed Rep
# 3214   Start = 27051989  End = 27051989   Country:Iran Islam Rep
# 4890   Start = 01091923  End = 01091923            Country:Japan
# 5675   Start = 07031999  End = 13031999   Country:United Kingdom
# 5691   Start = 07271976  End = 07271976            Country:China
# 5959   Start = 01032008  End = 14032008        Country:Indonesia
# 6222   Start = 00061988  End = 00061988         Country:Ethiopia
# 6388   Start = 07031999  End = 10041999          Country:Belarus
# 6535   Start = 19041989  End = 19041989    Country:United States
# 6905   Start = 00021979  End = 00021979        Country:Australia
# 7699   Start = 14081989  End = 14081989       Country:Bangladesh
# 7951   Start = 20032004  End = 20032004          Country:Nigeria
# 9139   Start = 19122001  End = 22122001     Country:South Africa
# 9376   Start = 02082005  End = 04082005        Country:Korea Rep
# 10646  Start = 12111909  End = 12111909            Country:Haiti
# 11658  Start = 25051992  End = 25051992             Country:Cuba
# 12180  Start = 17121997  End = 17121997           Country:Russia
# 12353  Start = 09121970  End = 09121970             Country:Peru
# 14121  Start = 06001988  End = 00001988            Country:China
#
#                                            col4  \
# 1279     Location : Sapouy,Gaoua:Mangodar:B ...
# 2152    Location : Minamata,Hishikari:Kinka ...
# 2402            Location : Lower Saxony,Bavaria
# 3214    Location : Fars,Yasuj:Kohkiluyeh-Bo ...
# 4890   Location : Kanto plaine (Yokohama,To ...
# 5675    Location : Malton,Old Malton:Norton ...
# 5691          Location : Tangshan:Pek.,Tientsin
# 5959    Location : Lamongan:Ngawi,Bojonego  ...
# 6222                  Location : Tigray,Eritrea
# 6388   Location : Brest,Gomel and Minsk reg ...
# 6535                 Location : Atlantique ocea
# 6905     Location : Act:Gouldburn,Yass:Mitt ...
# 7699    Location : Sylhet,Bandarban:Cox's B ...
# 7951   Location : Between Sa,go and Ifo (Og ...
# 9139   Location : Greater Tubatse,Thembisil ...
# 9376   Location : North Jeolla,South Jeolla ...
# 10646             Location : Cul de Sac,Leogane
# 11658   Location : Granma,Santiago de Cuba: ...
# 12180             Location : Bashkiria,Orenburg
# 12353                   Location : Piura,Tumbes
# 14121    Location : Hubei,Jiangsu:Henan:Anh ...
#
#                                      col5  \
# 1279                        Type:Epidemic
# 2152                           Type:Flood
# 2402                           Type:Storm
# 3214   Type:Earthquake (seismic activity)
# 4890   Type:Earthquake (seismic activity)
# 5675                           Type:Flood
# 5691   Type:Earthquake (seismic activity)
# 5959                           Type:Flood
# 6222              Type:Insect infestation
# 6388                           Type:Flood
# 6535              Type:Transport Accident
# 6905                        Type:Wildfire
# 7699                           Type:Flood
# 7951              Type:Transport Accident
# 9139                           Type:Flood
# 9376                           Type:Flood
# 10646                          Type:Storm
# 11658  Type:Earthquake (seismic activity)
# 12180                       Type:Epidemic
# 12353  Type:Earthquake (seismic activity)
# 14121                        Type:Drought
#
#                                          col6  \
# 1279   Sub_Type:Bacterial Infectious Diseases
# 2152                   Sub_Type:General flood
# 2402                             Sub_Type:nan
# 3214     Sub_Type:Earthquake (ground shaking)
# 4890     Sub_Type:Earthquake (ground shaking)
# 5675                   Sub_Type:General flood
# 5691     Sub_Type:Earthquake (ground shaking)
# 5959                   Sub_Type:General Flood
# 6222                          Sub_Type:Locust
# 6388                   Sub_Type:General flood
# 6535                           Sub_Type:Water
# 6905            Sub_Type:Scrub/grassland fire
# 7699                   Sub_Type:General flood
# 7951                            Sub_Type:Road
# 9139                     Sub_Type:Flash flood
# 9376                     Sub_Type:Flash flood
# 10646               Sub_Type:Tropical cyclone
# 11658    Sub_Type:Earthquake (ground shaking)
# 12180      Sub_Type:Viral Infectious Diseases
# 12353    Sub_Type:Earthquake (ground shaking)
# 14121                        Sub_Type:Drought
#
#                                                col7                col8  \
# 1279                               Names:Meningitis     Killed = 250. 0
# 2152                                      Names:nan      Killed = 23. 0
# 2402                                      Names:nan        Killed = nan
# 3214                                      Names:nan     Killed = 100. 0
# 4890                                      Names:nan  Killed = 143000. 0
# 5675                                      Names:nan        Killed = nan
# 5691                                      Names:nan  Killed = 242000. 0
# 5959                                      Names:nan       Killed = 3. 0
# 6222                        Names:Locusts:armyworms        Killed = nan
# 6388                                      Names:nan       Killed = 2. 0
# 6535                              Names:Boat 'Iowa'      Killed = 47. 0
# 6905                                      Names:nan        Killed = nan
# 7699                                      Names:nan     Killed = 180. 0
# 7951                                      Names:nan      Killed = 25. 0
# 9139                                      Names:nan       Killed = 5. 0
# 9376                                      Names:nan      Killed = 18. 0
# 10646                                     Names:nan     Killed = 150. 0
# 11658                                     Names:nan        Killed = nan
# 12180  Names:Haemorrhagic fever with renal syndrome        Killed = nan
# 12353                                     Names:nan      Killed = 29. 0
# 14121                                     Names:nan    Killed = 1400. 0
#
#                         col9           col10           col11 col12 col13
# 1279       Affected = 2000.0      Cost = nan  ID = 2008-0076   NaN   NaN
# 2152        Affected = 814.0      Cost = 7.0  ID = 2003-0343   NaN   NaN
# 2402          Affected = nan     Cost = 22.0  ID = 1974-0043   NaN   NaN
# 3214        Affected = 217.0      Cost = nan  ID = 1989-0090   NaN   NaN
# 4890     Affected = 203733.0    Cost = 600.0  ID = 1923-0006   NaN   NaN
# 5675        Affected = 330.0    Cost = 32.68  ID = 1999-0091   NaN   NaN
# 5691     Affected = 164000.0   Cost = 5600.0  ID = 1976-0050   NaN   NaN
# 5959      Affected = 12000.0      Cost = nan  ID = 2008-0108   NaN   NaN
# 6222          Affected = nan      Cost = nan  ID = 1988-0243   NaN   NaN
# 6388       Affected = 2000.0     Cost = 4.38  ID = 1999-0132   NaN   NaN
# 6535          Affected = nan      Cost = nan  ID = 1989-0489   NaN   NaN
# 6905          Affected = nan     Cost = 4.09  ID = 1979-0241   NaN   NaN
# 7699     Affected = 200000.0      Cost = nan  ID = 1989-0119   NaN   NaN
# 7951          Affected = 6.0      Cost = nan  ID = 2004-0118   NaN   NaN
# 9139        Affected = 312.0      Cost = nan  ID = 2001-0664   NaN   NaN
# 9376      Affected = 14510.0      Cost = nan  ID = 2005-0392   NaN   NaN
# 10646         Affected = nan      Cost = nan  ID = 1909-0012   NaN   NaN
# 11658      Affected = 5869.0      Cost = nan  ID = 1992-0067   NaN   NaN
# 12180      Affected = 4538.0      Cost = nan  ID = 1997-0510   NaN   NaN
# 12353     Affected = 15252.0      Cost = 2.0  ID = 1970-0068   NaN   NaN
# 14121  Affected = 49000000.0  Cost = 942.887  ID = 1988-9237   NaN   NaN

# %%
# Drop the two unused columns
data.drop(["col12","col13"], axis=1, inplace=True)

# %% [markdown]
# ### Check all Records have 11 Columns

# %%
# find any records without a value in col11
data[pd.isnull(data["col11"])]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %% [markdown]
# There are none, so all records now have 11 attributes

# %% [markdown]
# ### Check the Dataframe Structure

# %%
# Check the structure now
data.describe()
# Out:
#                     col1            col2           col3            col4  \
# count              14350           14350          14350           14350
# unique              8380            8387            228           10570
# top     Start = 00072000  End = 00001983  Country:China  Location : nan
# freq                  23              31           1042            1830
#
#                            col5          col6       col7          col8  \
# count                     14350         14350      14350         14350
# unique                       18            47       2227           852
# top     Type:Transport Accident  Sub_Type:nan  Names:nan  Killed = nan
# freq                       3367          1835       9792          3045
#
#                   col9       col10           col11
# count            14350       14350           14350
# unique            2905        1085           13694
# top     Affected = nan  Cost = nan  ID = 2005-0713
# freq              5464       11323              21

# %%
# Check the column data types
data.dtypes
# Out:
# col1     object
# col2     object
# col3     object
# col4     object
# col5     object
# col6     object
# col7     object
# col8     object
# col9     object
# col10    object
# col11    object
# dtype: object

# %% [markdown]
# ## Task 2: Parse the Data

# %% [markdown]
# ### Step 1: Check Column Attributes are Consistent
#
# Attribute names are embedded in the column values, so check to make sure all values in a column are for the same attribute

# %%
data[~ data.col1.str.match(r"^Start = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col2.str.match(r"^End = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col3.str.match(r"^Country:", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col4.str.match(r"^Location : ", as_indexer=True)]
# Out:
#                    col1            col2           col3  \
# 16     Start = 02082000  End = 30082000  Country:India
# 36     Start = 24031998  End = 24031998  Country:India
# 110    Start = 08091992  End = 31091992  Country:India
# 116    Start = 00071970  End = 00071970  Country:India
# 121    Start = 19081998  End = 19081998  Country:India
# 134    Start = 28081996  End = 28081996  Country:India
# 160    Start = 00051979  End = 00051979  Country:India
# 165    Start = 00101964  End = 00101964  Country:India
# 169    Start = 22061997  End = 28061997  Country:India
# 173    Start = 14011999  End = 14011999  Country:India
# 195    Start = 07051986  End = 07051986  Country:India
# 209    Start = 01121972  End = 01121972  Country:India
# 256    Start = 25011994  End = 25011994  Country:India
# 259    Start = 00081984  End = 00081984  Country:India
# 260    Start = 08051997  End = 08051997  Country:India
# 267    Start = 07031979  End = 07031979  Country:India
# 280    Start = 20101996  End = 20101996  Country:India
# 291    Start = 00071978  End = 00071978  Country:India
# 319    Start = 07091996  End = 07091996  Country:India
# 329    Start = 19101990  End = 19101990  Country:India
# 330    Start = 22101997  End = 22101997  Country:India
# 335    Start = 17071999  End = 17071999  Country:India
# 370    Start = 15121998  End = 15121998  Country:India
# 371    Start = 08091976  End = 08091976  Country:India
# 376    Start = 23091993  End = 23091993  Country:India
# 389    Start = 00051994  End = 00101994  Country:India
# 410    Start = 07061999  End = 07061999  Country:India
# 411    Start = 31031998  End = 31031998  Country:India
# 443    Start = 13061985  End = 13061985  Country:India
# 461    Start = 01111989  End = 01111989  Country:India
# ...                 ...             ...            ...
# 13782  Start = 17061992  End = 24061992  Country:India
# 13784  Start = 13061990  End = 18061990  Country:India
# 13787  Start = 00071983  End = 00071983  Country:India
# 13817  Start = 09081999  End = 09081999  Country:India
# 13868  Start = 12111993  End = 12111993  Country:India
# 13873  Start = 00041999  End = 00041999  Country:India
# 13891  Start = 08052000  End = 08052000  Country:India
# 13925  Start = 07051991  End = 08051991  Country:India
# 13942  Start = 13081989  End = 13081989  Country:India
# 13960  Start = 00111975  End = 00111975  Country:India
# 13967  Start = 03082008  End = 03082008  Country:India
# 13974  Start = 26062003  End = 26062003  Country:India
# 13981  Start = 02122005  End = 03122005  Country:India
# 14003  Start = 27052005  End = 27052005  Country:India
# 14009  Start = 21042005  End = 21042005  Country:India
# 14033  Start = 11062000  End = 11062000  Country:India
# 14036  Start = 14091997  End = 14091997  Country:India
# 14055  Start = 30092008  End = 30092008  Country:India
# 14083  Start = 13011998  End = 13011998  Country:India
# 14097  Start = 16091998  End = 18091998  Country:India
# 14116  Start = 15092005  End = 15092005  Country:India
# 14125  Start = 00071980  End = 00071980  Country:India
# 14225  Start = 29102005  End = 29102005  Country:India
# 14245  Start = 31052006  End = 04062006  Country:India
# 14247  Start = 09091993  End = 17091993  Country:India
# 14248  Start = 18022003  End = 18022003  Country:India
# 14261  Start = 21111986  End = 21111986  Country:India
# 14294  Start = 25052006  End = 02062006  Country:India
# 14305  Start = 25081990  End = 25081990  Country:India
# 14320  Start = 00071975  End = 00071975  Country:India
#
#                                             col4  \
# 16       Locations : Gujarat:Andhra Pradesh: ...
# 36      Locations : Tanton:Jaleshwar (Midnap ...
# 110      Locations : Uttar Pradesh:Jammu:Mad ...
# 116      Locations : North-East:Western:Nort ...
# 121    Locations : Mansuna village (Uttar Pr ...
# 134               Locations : Sone River (Bihar)
# 160                            Locations : Bihar
# 165                   Locations : Andhra Pradesh
# 169      Locations : Mehsana:Gandhi Nagar:Ah ...
# 173                       Locations : Sabarimala
# 195                            Locations : Patna
# 209                      Locations : Madras City
# 256                         Locations : Assanone
# 259     Locations : W Bengal:Uttar Pradesh & ...
# 260                 Locations : Himachal Pradesh
# 267                    Locations : Vishakapatnam
# 280               Locations : Bela river (Bihar)
# 291                  Locations : North:Northeast
# 319                         Locations : Cuddapah
# 329                Locations : Maharashtra state
# 330             Locations : Ganges (Murshidabad)
# 335             Locations : Agra (Uttar Pradesh)
# 370      Locations : Uttar Pradesh:Bihar:Raj ...
# 371     Locations : Midnapore:Parganas distr ...
# 376                           Locations : Bombay
# 389      Locations : Assam:Arunachal Pradesh:...
# 410                  Locations : Karnataka state
# 411                           Locations : Sikkim
# 443                             Locations : Agra
# 461                        Locations : Sakaldiha
# ...                                          ...
# 13782    Locations : Kerala:Gujarat:Orissa s ...
# 13784           Locations : Bombay (Assam state)
# 13787   Locations : Upper Assama:Central Sik ...
# 13817                 Locations : Madhya Pradesh
# 13868                     Locations : Latur area
# 13873    Locations : Orissa:Andhra Pradesh:G ...
# 13891                      Locations : Midnapore
# 13925    Locations : Assam:Tripura:Arunachal ...
# 13942                    Locations : Near Bhopal
# 13960                      Locations : Sillewera
# 13967               Locations : Himachal Pradesh
# 13974   Locations : Retam river:Mandsaur dis ...
# 13981                     Locations : Tamil Nadu
# 14003  Locations : Mokokchung district (Naga ...
# 14009                  Locations : Gujarat state
# 14033            Locations : Banihal (Cachemire)
# 14036       Locations : Visakhapatnam (Hyderabad
# 14055  Locations : Jodhpur (Rajasthan state) ...
# 14083                    Locations : West Bengal
# 14097   Locations : Gujarat:Maharashtra stat ...
# 14116              Locations : Khusropur (Bihar)
# 14125                            Locations : nan
# 14225        Locations : Andra Pradesh (Sud-est)
# 14245            Locations : Maharashtra:Gujarat
# 14247                  Locations : Uttar Pradesh
# 14248       Locations : Dholatar (Gujarat state)
# 14261                      Locations : Karnataka
# 14294                   Locations : Kerala state
# 14305                        Locations : Gujarat
# 14320                Locations : Northwest:Bihar
#
#                                      col5  \
# 16                             Type:Flood
# 36                             Type:Storm
# 110                            Type:Flood
# 116                            Type:Flood
# 121                Type:Mass movement wet
# 134               Type:Transport Accident
# 160              Type:Extreme temperature
# 165                            Type:Flood
# 169                            Type:Flood
# 173           Type:Miscellaneous accident
# 195               Type:Transport Accident
# 209                            Type:Storm
# 256              Type:Industrial Accident
# 259                            Type:Flood
# 260               Type:Transport Accident
# 267              Type:Industrial Accident
# 280               Type:Transport Accident
# 291                            Type:Flood
# 319               Type:Transport Accident
# 329               Type:Transport Accident
# 330               Type:Transport Accident
# 335               Type:Transport Accident
# 370              Type:Extreme temperature
# 371                            Type:Storm
# 376                Type:Mass movement wet
# 389                            Type:Flood
# 410               Type:Transport Accident
# 411                Type:Mass movement wet
# 443               Type:Transport Accident
# 461               Type:Transport Accident
# ...                                   ...
# 13782                          Type:Storm
# 13784                          Type:Flood
# 13787                          Type:Flood
# 13817             Type:Transport Accident
# 13868  Type:Earthquake (seismic activity)
# 13873            Type:Extreme temperature
# 13891             Type:Transport Accident
# 13925                          Type:Flood
# 13942             Type:Transport Accident
# 13960            Type:Industrial Accident
# 13967         Type:Miscellaneous accident
# 13974             Type:Transport Accident
# 13981                          Type:Flood
# 14003                          Type:Flood
# 14009             Type:Transport Accident
# 14033             Type:Transport Accident
# 14036            Type:Industrial Accident
# 14055         Type:Miscellaneous accident
# 14083             Type:Transport Accident
# 14097                          Type:Flood
# 14116            Type:Industrial Accident
# 14125                          Type:Flood
# 14225             Type:Transport Accident
# 14245                          Type:Flood
# 14247                          Type:Flood
# 14248                          Type:Storm
# 14261             Type:Transport Accident
# 14294                          Type:Flood
# 14305                          Type:Storm
# 14320                          Type:Flood
#
#                                        col6                     col7  \
# 16                   Sub_Type:General flood                Names:nan
# 36                     Sub_Type:Local storm                Names:nan
# 110                  Sub_Type:General flood                Names:nan
# 116                            Sub_Type:nan                Names:nan
# 121                      Sub_Type:Landslide                Names:nan
# 134                          Sub_Type:Water                Names:nan
# 160                      Sub_Type:Heat wave                Names:nan
# 165                            Sub_Type:nan                Names:nan
# 169                  Sub_Type:General flood                Names:nan
# 173                       Sub_Type:Collapse               Names:Hill
# 195                          Sub_Type:Water                Names:nan
# 209               Sub_Type:Tropical cyclone                Names:nan
# 256                      Sub_Type:Explosion          Names:Coal mine
# 259                            Sub_Type:nan                Names:nan
# 260                           Sub_Type:Road                Names:nan
# 267                           Sub_Type:Fire               Names:Port
# 280                          Sub_Type:Water              Names:Ferry
# 291                            Sub_Type:nan                Names:nan
# 319                           Sub_Type:Road                Names:nan
# 329                           Sub_Type:Road                Names:nan
# 330                          Sub_Type:Water                Names:nan
# 335                           Sub_Type:Rail                Names:nan
# 370                      Sub_Type:Cold wave                Names:nan
# 371               Sub_Type:Tropical cyclone                Names:nan
# 376                      Sub_Type:Landslide                Names:nan
# 389                            Sub_Type:nan                Names:nan
# 410                           Sub_Type:Road                Names:nan
# 411                      Sub_Type:Avalanche                Names:nan
# 443                           Sub_Type:Rail                Names:nan
# 461                           Sub_Type:Rail                Names:nan
# ...                                     ...                      ...
# 13782                  Sub_Type:Local storm                Names:nan
# 13784                Sub_Type:General flood                Names:nan
# 13787                          Sub_Type:nan                Names:nan
# 13817                         Sub_Type:Road                Names:nan
# 13868  Sub_Type:Earthquake (ground shaking)                Names:nan
# 13873                    Sub_Type:Heat wave                Names:nan
# 13891                         Sub_Type:Road                Names:nan
# 13925    Sub_Type:Storm surge/coastal flood                Names:nan
# 13942                         Sub_Type:Road                Names:nan
# 13960                        Sub_Type:Other               Names:Mine
# 13967                        Sub_Type:Other                Names:nan
# 13974                         Sub_Type:Road                Names:nan
# 13981                Sub_Type:General flood                Names:nan
# 14003                Sub_Type:General flood                Names:nan
# 14009                         Sub_Type:Rail                Names:nan
# 14033                         Sub_Type:Road                Names:nan
# 14036                         Sub_Type:Fire       Names:Oil refinery
# 14055                        Sub_Type:Other           Names:Stampede
# 14083                         Sub_Type:Road                Names:nan
# 14097                  Sub_Type:Flash flood                Names:nan
# 14116                    Sub_Type:Explosion  Names:Fireworks factory
# 14125                          Sub_Type:nan                Names:nan
# 14225                         Sub_Type:Rail  Names:Accident de train
# 14245                Sub_Type:General flood                Names:nan
# 14247                Sub_Type:General flood                Names:nan
# 14248             Sub_Type:Tropical cyclone                Names:nan
# 14261                         Sub_Type:Road                Names:nan
# 14294                Sub_Type:General flood                Names:nan
# 14305                  Sub_Type:Local storm                Names:nan
# 14320                          Sub_Type:nan                Names:nan
#
#                         col8                   col9           col10  \
# 16           Killed = 867. 0  Affected = 22000000.0     Cost = 43.0
# 36           Killed = 250. 0     Affected = 40500.0     Cost = 10.0
# 110     Killed = 499. 999999     Affected = 70000.0    Cost = 57.85
# 116     Killed = 626. 999999  Affected = 10351000.0    Cost = 101.2
# 121      Killed = 36. 999999         Affected = nan      Cost = nan
# 134      Killed = 29. 999999         Affected = nan      Cost = nan
# 160     Killed = 299. 999999         Affected = nan      Cost = nan
# 165             Killed = nan     Affected = 18400.0      Cost = 0.5
# 169     Killed = 110. 999999   Affected = 1000000.0    Cost = 153.8
# 173      Killed = 50. 999999        Affected = 63.0      Cost = nan
# 195      Killed = 39. 999999         Affected = nan      Cost = nan
# 209           Killed = 80. 0     Affected = 30000.0      Cost = nan
# 256           Killed = 96. 0         Affected = nan      Cost = nan
# 259          Killed = 245. 0         Affected = nan      Cost = nan
# 260           Killed = 70. 0         Affected = 8.0      Cost = nan
# 267            Killed = 9. 0      Affected = 1000.0      Cost = nan
# 280           Killed = 25. 0         Affected = nan      Cost = nan
# 291         Killed = 3800. 0  Affected = 32000000.0    Cost = 165.0
# 319      Killed = 40. 000001         Affected = nan      Cost = nan
# 329      Killed = 36. 000001         Affected = nan      Cost = nan
# 330      Killed = 59. 000001         Affected = nan      Cost = nan
# 335      Killed = 17. 000001       Affected = 209.0      Cost = nan
# 370     Killed = 100. 000001         Affected = nan      Cost = nan
# 371      Killed = 40. 000001         Affected = nan      Cost = nan
# 376      Killed = 20. 000001        Affected = 25.0      Cost = nan
# 389    Killed = 2001. 000001  Affected = 12060050.0    Cost = 175.0
# 410      Killed = 94. 000001        Affected = 34.0      Cost = nan
# 411      Killed = 24. 000001         Affected = 6.0      Cost = nan
# 443      Killed = 35. 000001       Affected = 100.0      Cost = nan
# 461      Killed = 52. 000001        Affected = 60.0      Cost = nan
# ...                      ...                    ...             ...
# 13782         Killed = 60. 0         Affected = nan      Cost = nan
# 13784         Killed = 21. 0         Affected = nan      Cost = nan
# 13787        Killed = 197. 0    Affected = 250000.0      Cost = nan
# 13817         Killed = 39. 0         Affected = nan      Cost = nan
# 13868           Killed = nan       Affected = 525.0      Cost = nan
# 13873        Killed = 140. 0         Affected = nan      Cost = nan
# 13891         Killed = 20. 0        Affected = 19.0      Cost = nan
# 13925         Killed = 30. 0   Affected = 2000000.0      Cost = nan
# 13942         Killed = 20. 0         Affected = nan      Cost = nan
# 13960         Killed = 10. 0         Affected = nan      Cost = nan
# 13967        Killed = 148. 0        Affected = 48.0      Cost = nan
# 13974         Killed = 43. 0         Affected = 7.0      Cost = nan
# 13981         Killed = 30. 0    Affected = 200000.0      Cost = nan
# 14003         Killed = 14. 0        Affected = 12.0      Cost = nan
# 14009         Killed = 17. 0       Affected = 150.0      Cost = nan
# 14033         Killed = 27. 0        Affected = 25.0      Cost = nan
# 14036         Killed = 56. 0    Affected = 100031.0     Cost = 19.2
# 14055        Killed = 224. 0       Affected = 150.0      Cost = nan
# 14083         Killed = 66. 0         Affected = nan      Cost = nan
# 14097         Killed = 90. 0     Affected = 50000.0      Cost = nan
# 14116         Killed = 35. 0        Affected = 20.0      Cost = nan
# 14125        Killed = 600. 0         Affected = nan      Cost = nan
# 14225        Killed = 110. 0        Affected = 92.0      Cost = nan
# 14245         Killed = 41. 0         Affected = nan      Cost = nan
# 14247        Killed = 260. 0         Affected = nan    Cost = 500.0
# 14248          Killed = 5. 0       Affected = 140.0      Cost = nan
# 14261         Killed = 30. 0         Affected = nan      Cost = nan
# 14294         Killed = 32. 0     Affected = 10800.0      Cost = nan
# 14305        Killed = 120. 0         Affected = nan   Cost = 2200.0
# 14320        Killed = 350. 0  Affected = 34000000.0  Cost = 714.259
#
#                 col11
# 16     ID = 2000-0445
# 36     ID = 1998-0106
# 110    ID = 1992-0083
# 116    ID = 1970-0034
# 121    ID = 1998-0262
# 134    ID = 1996-0378
# 160    ID = 1979-0045
# 165    ID = 1964-0055
# 169    ID = 1997-0337
# 173    ID = 1999-0011
# 195    ID = 1986-0320
# 209    ID = 1972-0063
# 256    ID = 1994-0016
# 259    ID = 1984-0323
# 260    ID = 1997-0422
# 267    ID = 1979-0031
# 280    ID = 1996-0380
# 291    ID = 1978-0087
# 319    ID = 1996-0391
# 329    ID = 1990-0551
# 330    ID = 1997-0403
# 335    ID = 1999-0236
# 370    ID = 1998-0455
# 371    ID = 1976-0063
# 376    ID = 1993-0208
# 389    ID = 1994-0068
# 410    ID = 1999-0205
# 411    ID = 1998-0439
# 443    ID = 1985-0070
# 461    ID = 1989-0233
# ...               ...
# 13782  ID = 1992-0211
# 13784  ID = 1990-0714
# 13787  ID = 1983-0089
# 13817  ID = 1999-0696
# 13868  ID = 1993-0581
# 13873  ID = 1999-0125
# 13891  ID = 2000-0236
# 13925  ID = 1991-0338
# 13942  ID = 1989-0526
# 13960  ID = 1975-0153
# 13967  ID = 2008-0319
# 13974  ID = 2003-0305
# 13981  ID = 2005-0677
# 14003  ID = 2005-0314
# 14009  ID = 2005-0208
# 14033  ID = 2000-0313
# 14036  ID = 1997-0222
# 14055  ID = 2008-0436
# 14083  ID = 1998-0488
# 14097  ID = 1998-0449
# 14116  ID = 2005-0811
# 14125  ID = 1980-0324
# 14225  ID = 2005-0607
# 14245  ID = 2006-0265
# 14247  ID = 1993-0325
# 14248  ID = 2003-0100
# 14261  ID = 1986-0359
# 14294  ID = 2006-0263
# 14305  ID = 1990-0397
# 14320  ID = 1975-0037
#
# [943 rows x 11 columns]

# %% [markdown]
# Col4 has inconsistent attribute names - Location and Locations

# %%
# Check to make sure col4 values all start with Location or Locations
data[~ data.col4.str.match(r"^Locations? : ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col5.str.match(r"^Type:", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col6.str.match(r"^Sub_Type:", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col7.str.match(r"^Names:", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col8.str.match(r"^Killed = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col9.str.match(r"^Affected = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col10.str.match(r"^Cost = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %%
data[~ data.col11.str.match(r"^ID = ", as_indexer=True)]
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]
# Index: []

# %% [markdown]
# ### Step 2: Extract and Set the Column Names

# %%
# Extract the attribute names from the first record and use these to set the column names
columnNames = []
for i in range(0,11):
    columnNames.append(re.match(r"^(.+?) *[=:]",data.iloc[0][i]).group(1))
data.columns = columnNames

# List the column names
data.columns
# Out:
# Index([u'Start', u'End', u'Country', u'Location', u'Type', u'Sub_Type',
#        u'Names', u'Killed', u'Affected', u'Cost', u'ID'],
#       dtype='object')

# %%
# Strip out the column names from the attributes
for i in range(0,11):
    data[data.columns[i]] = data[data.columns[i]].str.extract(r"^.+?[=:] *(.+)", expand=False)

# Check a few records    
data.head()
# Out:
#       Start       End  Country                      Location  \
# 0  10061965  10061965    Japan                           nan
# 1  08092004  08092004  Grenada                           nan
# 2  15031995  15031995   Russia  Kalmoukie:Daghestan (Mer ...
# 3  00021983  00021983     Cuba  Santiago de Cuba:Pinar d ...
# 4  00001983  00001983    Nepal                           nan
#
#                  Type          Sub_Type  Names Killed  Affected   Cost  \
# 0               Storm  Tropical cyclone  Dinah  61. 0   30000.0    nan
# 1               Storm  Tropical cyclone   Ivan  39. 0   60000.0  889.0
# 2  Transport Accident             Water    nan  52. 0       nan    nan
# 3               Flood               nan    nan  15. 0  164575.0   60.0
# 4   Mass movement wet         Landslide    nan  21. 0       nan    nan
#
#           ID
# 0  1965-0036
# 1  2004-0462
# 2  1995-0362
# 3  1983-0042
# 4  1983-0526

# %% [markdown]
# ### Step 3: Check for an Index Attribute

# %%
# Display the current structure
data.describe()
# Out:
#            Start       End Country Location                Type Sub_Type  \
# count      14350     14350   14350    14350               14350    14350
# unique      8380      8387     228    10531                  18       47
# top     00072000  00001983   China      nan  Transport Accident      nan
# freq          23        31    1042     1892                3367     1835
#
#         Names Killed Affected   Cost         ID
# count   14350  14350    14350  14350      14350
# unique   2227    852     2905   1085      13694
# top       nan    nan      nan    nan  2005-0713
# freq     9792   3045     5464  11323         21

# %% [markdown]
# ** Is there an index column?**
#
# ID looks like it should be used to index the rows, but it is not unique so cannot be used. Leave the data frame with default indexing

# %% [markdown]
# ### Step 4: Set NaN Values

# %%
# Convert the "nan" strings to NaN
data.replace("nan", np.nan, inplace=True)

# Check a few records
data.head()
# Out:
#       Start       End  Country                      Location  \
# 0  10061965  10061965    Japan                           NaN
# 1  08092004  08092004  Grenada                           NaN
# 2  15031995  15031995   Russia  Kalmoukie:Daghestan (Mer ...
# 3  00021983  00021983     Cuba  Santiago de Cuba:Pinar d ...
# 4  00001983  00001983    Nepal                           NaN
#
#                  Type          Sub_Type  Names Killed  Affected   Cost  \
# 0               Storm  Tropical cyclone  Dinah  61. 0   30000.0    NaN
# 1               Storm  Tropical cyclone   Ivan  39. 0   60000.0  889.0
# 2  Transport Accident             Water    NaN  52. 0       NaN    NaN
# 3               Flood               NaN    NaN  15. 0  164575.0   60.0
# 4   Mass movement wet         Landslide    NaN  21. 0       NaN    NaN
#
#           ID
# 0  1965-0036
# 1  2004-0462
# 2  1995-0362
# 3  1983-0042
# 4  1983-0526

# %% [markdown]
# ### Step 5: Set the "Start" and "End" Column Datatypes to Datetime
#
# The Start and End columns are dates and appear to be in ddmmyyyy format
#
# Before converting these columns to Datetime check they are all valid dates

# %% [markdown]
# Dictionary object storing the days in the month, used by several functions in this section

# %%
# Dictionary that specifies the number of days in each month
monthDict = {"01":"31", "02":"28", "03":"31", "04":"30", "05":"31", "06":"30",
             "07":"31", "08":"31", "09":"30", "10":"31", "11":"30", "12":"31"}

# %% [markdown]
# #### Function to Check for Date Errors
#
# Function Name: checkDate
#
# Input Parameters:
# - value - a string containing the date to check, should be 8 digits in ddmmyyyy format
#
# Return Value:
# - A string containing the first problem detected for the date
#  - "Not 8 digits" - the date is not 8 digits long
#  - "Month is 0" - the month component is zero
#  - "Month is too big" - the month component is greater than 12
#  - "Day is 0" - the day component is zero
#  - "Day is too big" - the day component is greater than the days in the month
#  - "Other" - there is some other probloem with the date
#  - "Valid" - the date is valid
#
# Description:
#
# Checks the date to ensure it is valid and in ddmmyyyy format. If not valid attempts to determine the problem by checking the length is 8, the month between 1 and 12 and the day a valid day for the month. Returns a message indicating the problem.

# %%
def checkDate(value):
    check1 = re.match(r"^\d{8}$", value)          # Check the value is 8 digits
    if check1 == None:
        return "Not 8 digits"                    # Return "Not 8 digits" if not 8 digits
    try:
        dt.datetime.strptime(value, "%d%m%Y")    # Is the date valid?
        return "Valid"                           # Yes - Return "Valid"
    except:                                      # No - Figure out what the problem is
        day = value[0:2]                         # Split date into day ...
        month = value[2:4]                       # month ...
        year = value[4:8]                        # and year
        if month == "00":                        # Test for month specified as "00"
            return "Month is 0"
        elif int(month) > 12:                    # Test for month greater than "12"
            return "Month is too big"
        elif day == "00":                        # Test for day specified as "00"
            return "Day is 0"
        elif int(day) > int(monthDict[month]):   # Test for day greater than number of days in the month
            return "Day is too big"
        else:                                    # Something else is wrong
            return "Other"

# %% [markdown]
# #### Validate Start and End Fields
#
# Check the Start and End fields are valid dates and print a summary of the problems

# %%
df1 = data[["Start","End","Country"]].copy()
df1["StartErrors"] = df1.Start.apply(checkDate)
df1["EndErrors"] = df1.End.apply(checkDate)
pd.pivot_table(df1, values="Country", columns=["StartErrors", "EndErrors"], aggfunc=len)
# Out:
# StartErrors       EndErrors
# Day is 0          Day is 0             1956
#                   Day is too big          1
#                   Month is 0            257
#                   Valid                  63
# Day is too big    Day is too big          1
# Month is 0        Day is 0                5
#                   Month is 0            464
#                   Valid                   3
# Month is too big  Month is 0              1
#                   Month is too big      560
#                   Valid                  22
# Valid             Day is 0               41
#                   Day is too big          2
#                   Month is 0              5
#                   Month is too big       20
#                   Valid               10949
# dtype: int64

# %% [markdown]
# So there are:
# - A lot of records with the day and/or month set to "00"
# - A few records with the day greater than the days in the month
# - A lot of records with month greater than 12

# %% [markdown]
# A month greater than 12 may indicate the date is in mmddyyyy format
#
# Have a closer look at these records
#
# First, see which countries these records are for

# %%
df2 = df1[(df1.StartErrors == "Month is too big") | (df1.EndErrors == "Month is too big")]
pd.pivot_table(df2, values="Start", index=["Country"], columns=["StartErrors", "EndErrors"], aggfunc=len)
# Out:
# StartErrors Month is too big                                   Valid
# EndErrors         Month is 0 Month is too big Valid Month is too big
# Country
# China                    1.0            559.0  22.0             20.0
# Chine                    NaN              1.0   NaN              NaN

# %% [markdown]
# They are all for China (or "Chine" - China mis-spelt?)
#
# What do the other dates for China look like?

# %%
df2 = df1[df1.Country.isin(["China", "Chine"])]
pd.pivot_table(df2, values="Start", index=["Country"], columns=["StartErrors", "EndErrors"], aggfunc=len)
# Out:
# StartErrors Month is 0 Month is too big                             Valid  \
# EndErrors   Month is 0       Month is 0 Month is too big Valid Month is 0
# Country
# China            107.0              1.0            559.0  22.0        1.0
# Chine              NaN              NaN              1.0   NaN        NaN
#
# StartErrors
# EndErrors   Month is too big  Valid
# Country
# China                   20.0  332.0
# Chine                    NaN    NaN

# %% [markdown]
# A number of records with the month set to 0, but no records with invalid days
#
# About 40% of records are valid - about the proportion of days in the first 12 days of a month
#
# Lets see what happens if all dates for China are treated as in mmddyyyy format

# %% [markdown]
# #### Function to Check MMDDYYYY Dates
#
# Function Name: checkDate2
#
# Input Parameters:
# - value - a string containing the date to check, should be 8 digits in mmddyyyy format
#
# Return Value:
# - A string containing the first problem detected for the date
#  - "Not 8 digits" - the date is not 8 digits long
#  - "Month is 0" - the month component is zero
#  - "Month is too big" - the month component is greater than 12
#  - "Day is 0" - the day component is zero
#  - "Day is too big" - the day component is greater than the days in the month
#  - "Other" - there is some other probloem with the date
#  - "Valid" - the date is valid
#
# Description:
#
# This function is the same as the checkDate function, except that it expects the date to be in mmddyyyy format.
#
# Checks the date to ensure it is valid and in mmddyyyy format. If not valid attempts to determine the problem by checking the length is 8, the month between 1 and 12 and the day a valid day for the month. Returns a message indicating the problem.

# %%
def checkDate2(value):
    check1 = re.match(r"^\d{8}$", value)          # Check the value is 8 digits
    if check1 == None:
        return "Not 8 digits"                    # Return "Not 8 digits" if not 8 digits
    try:
        dt.datetime.strptime(value, "%m%d%Y")    # Is the date valid?
        return "Valid"                           # Yes - Return "Valid"
    except:                                      # No - Figure out what the problem is
        month = value[0:2]                       # Split date into month ...
        day = value[2:4]                         # day ...
        year = value[4:8]                        # and year
        if month == "00":                        # Test for month specified as "00"
            return "Month is 0"
        elif int(month) > 12:                    # Test for month greater than "12"
            return "Month is too big"
        elif day == "00":                        # Test for day specified as "00"
            return "Day is 0"
        elif int(day) > int(monthDict[month]):   # Test for day greater than number of days in the month
            return "Day is too big"
        else:                                    # Something else is wrong
            return "Other"

# %% [markdown]
# #### Validate China Dates
#
# Check the Start and End dates for all records for China assuming these dates are in mmddyyyy format

# %%
df1 = data[["Start","End","Country"]][data.Country.isin(["China", "Chine"])]
df1["StartErrors"] = df1.Start.apply(checkDate2)
df1["EndErrors"] = df1.End.apply(checkDate2)
pd.pivot_table(df1, values="Start", index=["Country"], columns=["StartErrors","EndErrors"], aggfunc=len)
# Out:
# StartErrors Day is 0            Month is 0    Valid
# EndErrors   Day is 0 Month is 0 Month is 0 Day is 0 Month is 0  Valid
# Country
# China           81.0       11.0       15.0      1.0        1.0  933.0
# Chine            NaN        NaN        NaN      NaN        NaN    1.0

# %% [markdown]
# Dates for China are mainly valid if mmddyyyy format assumed ...
#
# So tidy up the dates by swapping the day and month components for records for China

# %% [markdown]
# #### Function to Swap the Day and Month Components of a Date
#
# Function Name: swapDayMonth
#
# Input Parameters:
# - value - a string containing the date to fix, should be 8 digits in mmddyyyy format
#
# Return Value:
# - A string containing the fixed date
#
# Description:
#
# Swaps the day and month components of the date to convert from mmddyyyy format to ddmmyyyy format.

# %%
def swapDayMonth(value):
    month = value[0:2]          # extract the month
    day = value[2:4]            # extract the day
    year = value[4:8]           # extract the year
    return day + month + year   # return the date in ddmmyyyy format

# %% [markdown]
# #### Fix the Start and End Dates for China Records

# %%
# List of countries to fix
fixList = ["China", "Chine"]

# Fix the Start dates for China
data.loc[data.Country.isin(fixList),"Start"] = data.loc[data.Country.isin(fixList),"Start"].apply(swapDayMonth)

#Fix the End dates for China
data.loc[data.Country.isin(fixList),"End"] = data.loc[data.Country.isin(fixList),"End"].apply(swapDayMonth)

data[data.Country.isin(fixList)].head()
# Out:
#        Start       End Country                       Location  \
# 29  05082005  05082005   China                   Huize County
# 35  20062006  20062006   China                          Gansu
# 38  18011989  18011989   China                         Huinan
# 42  16021995  16021995   China                 Guangxi Region
# 44  27102005  27102005   China  Dianzhangou Zhongxing (Xi ...
#
#                              Type                     Sub_Type  \
# 29  Earthquake (seismic activity)  Earthquake (ground shaking)
# 35  Earthquake (seismic activity)  Earthquake (ground shaking)
# 38             Transport Accident                         Rail
# 42                          Storm                  Local storm
# 44            Industrial Accident                    Explosion
#
#                                  Names      Killed Affected Cost         ID
# 29                                 NaN         NaN  18509.0  NaN  2005-0740
# 35                                 NaN         NaN    130.0  NaN  2006-0464
# 38                                 NaN       32. 0      NaN  NaN  1989-0504
# 42                                 NaN   3. 999999  15365.0  NaN  1995-0031
# 44  Explosion dans une mine de charbon  15. 999999      NaN  NaN  2005-0609

# %% [markdown]
# Check to see what date errors are left

# %%
df1 = data[["Start","End","Country"]].copy()
df1["StartErrors"] = df1.Start.apply(checkDate)
df1["EndErrors"] = df1.End.apply(checkDate)
pd.pivot_table(df1, values="Country", columns=["StartErrors", "EndErrors"], aggfunc=len)
# Out:
# StartErrors     EndErrors
# Day is 0        Day is 0           2037
#                 Day is too big        1
#                 Month is 0          268
#                 Valid                63
# Day is too big  Day is too big        1
# Month is 0      Day is 0              5
#                 Month is 0          372
#                 Valid                 3
# Valid           Day is 0             42
#                 Day is too big        2
#                 Month is 0            5
#                 Valid             11551
# dtype: int64

# %% [markdown]
# Have a look at the records where the day component of the Start or End record is greater than the number of days in the month

# %%
df1[(df1.StartErrors == "Day is too big") | (df1.EndErrors == "Day is too big")]
# Out:
#           Start       End       Country     StartErrors       EndErrors
# 110    08091992  31091992         India           Valid  Day is too big
# 4807   00111996  31041997  Sierra Leone        Day is 0  Day is too big
# 8419   31091992  31091992   Afghanistan  Day is too big  Day is too big
# 12067  01011998  31021998          Peru           Valid  Day is too big

# %% [markdown]
# All specify the 31st of a month with less than 31 days - so it should be safe to set these to the last day of the month
#
# #### Rules used to Fix Dates
#
# For Start Dates
# 1. If the month is "00" set the month to "01"
# 2. If the day is "00" set the day to "01"
# 3. If the day is greater than the days in the month, set to the last day of the month
#
# For End Dates
# 1. If the month is "00" set the month to "12"
# 2. If the day is "00" set to the last day of the month
# 3. If the day is greater than the days in the month, set to the last day of the month
#
# This assumes that if a day or month is set to "00" that only the month or year of the event is known, so the date range is set to cover the entire period. This has the disadvantage that it could lead any analysis on the data to the erroneous conclusion that the event lasted for the entire month or year. But setting both the Start and End to the same (e.g. the 1st of the month) could lead analysis to the equally erroneous conclusion that the event only lasted one day.

# %% [markdown]
# #### Function to Fix Invalid Dates
#
# Function Name: fixDate
#
# Input Parameters:
# - value - a string containing the date to fix
# - useMax - a boolean indicating whether or not to replace a "00" day/month with the maximum valid value, (default: False)
#
# Return Value:
# - The fixed date
#
# Description:
#
# If the value parameter is not a valid date in ddmmyyyy format, fix as follows:
# - If the month component is "00":
#  - If useMax is false set the month to "01"
#  - Else set the month to "12"
# - If the day component is "00"
#  - If useMax is false set the day to "01"
#  - Else set the day to the last day of the month
# - Test to see if the date is valid, if not the day is outside the valid range for the month, set the day to the last day of the month
#
# Note:
#
# This function is designed to fix only the known date issues in the data.dat data - it is not a full date fixing function

# %%
# Function to convert dates to a valid date in ddmmyyyy format
def fixDate(value, useMax=False):
    
    day = value[0:2]                                  # Extract the day component 
    month = value[2:4]                                # Extract the month component
    year = value[4:8]                                 # Extract the year component    

    if month == "00":                                 # If the month is "00" ... 
        month = "12" if useMax else "01"              # Correct the month dependig on the the useMax flag
        value = day + month + year                    # Date value to return

    if day == "00":                                   # If the day is "00" ... 
        day = monthDict[month] if useMax else "01"    # Correct the day depending on the useMax flag
        value = day + month + year                    # Date value to return

    try:
        dt.datetime.strptime(value, "%d%m%Y")         # Check the date is valid
    except:                                           # If not, the day must still be invalid
        day = monthDict[month]                        # Set to the last day of the month
        value = day + month + year                    # Date value to return
        dt.datetime.strptime(value, "%d%m%Y")         # Verify the date is now valid

    return value                                      # Return the fixed date

# %% [markdown]
# #### Set the Start Column Type to Datetime

# %%
# Fix invalid dates in the Start column
data["Start"] = data.Start.apply(fixDate)
# Convert the Start column to datetime format
data["Start"] = pd.to_datetime(data["Start"], format="%d%m%Y")

# %% [markdown]
# #### Set the End Column Type to Datetime

# %%
# Fix invalid dates in the End column
data["End"] = data.End.apply(fixDate, useMax=True)
# Convert the End column to datetime format
data["End"] = pd.to_datetime(data["End"], format="%d%m%Y")

# %%
# Check the results
data.head()
# Out:
#        Start        End  Country                      Location  \
# 0 1965-06-10 1965-06-10    Japan                           NaN
# 1 2004-09-08 2004-09-08  Grenada                           NaN
# 2 1995-03-15 1995-03-15   Russia  Kalmoukie:Daghestan (Mer ...
# 3 1983-02-01 1983-02-28     Cuba  Santiago de Cuba:Pinar d ...
# 4 1983-01-01 1983-12-31    Nepal                           NaN
#
#                  Type          Sub_Type  Names Killed  Affected   Cost  \
# 0               Storm  Tropical cyclone  Dinah  61. 0   30000.0    NaN
# 1               Storm  Tropical cyclone   Ivan  39. 0   60000.0  889.0
# 2  Transport Accident             Water    NaN  52. 0       NaN    NaN
# 3               Flood               NaN    NaN  15. 0  164575.0   60.0
# 4   Mass movement wet         Landslide    NaN  21. 0       NaN    NaN
#
#           ID
# 0  1965-0036
# 1  2004-0462
# 2  1995-0362
# 3  1983-0042
# 4  1983-0526

# %% [markdown]
# ### Step 6: Set the "Killed" and "Affected" Column Datatypes to Integer
#
# #### Discussion about Integer Representation
#
# The Pandas integer datatype does not allow NaN values. The two columns that should be integer datatype (Killed and Affected) both have NaN values. So we cannot change the datatype to integer and keep the NaN values stored as NaN. Options considered to resolve this are:
# 1. Convert the NaN values to an unused and obviously wrong integer such as -999 and set the column datatype to integer
#  - Advantages:
#  <ul>
#  <li>The column datatype matches the data</li>
#  </ul>
#  - Disadvantages:
#  <ul>
#  <li>Future processing will need to handle the -999 values correctly</li>
#  </ul>
# 2. Convert the value to a integer but set the column datatype to float
#  - Advantages:
#  <ul>
#  <li>The NaN values can be retained</li>
#  <li>The value is stored as a number so it can be used in numeric operations</li>
#  </ul>
#  - Disadvantages:
#  <ul>
#  <li>The column datatype doesn't match the data</li>
#  <li>The numbers are formatted with a trailing ".0" when displayed</li>
#  <li>The numbers need special treatment to be correctly formatted as integers in the CSV file</li>
#  </ul>
# 3. Convert the value to a integer but leave the column datatype as object (string)
#  - Advantages:
#  <ul>
#  <li>The value is correctly formatted in the output file</li>
#  <li>The value displays correctly</li>
#  <li>The NaN values can be retained</li>
#  </ul>
#  - Disadvantages:
#  <ul>
#  <li>The column datatype doesn't match the data</li>
#  <li>The values must be converted to a numeric type before being used in numeric operations</li>
#  </ul>
#
# Implemented Solution: The program implements Option 2 - convert the values to integers but set the column datatype to float.  Formatting will be applied to these values prior to writing the data to the CSV file so they are written as integers.

# %% [markdown]
# #### Process the "Killed" Column
#
# What data problems are there in the Killed column?

# %%
# Display a few records
data.Killed.head(10)
# Out:
# 0    61. 0
# 1    39. 0
# 2    52. 0
# 3    15. 0
# 4    21. 0
# 5      NaN
# 6    10. 0
# 7    51. 0
# 8      NaN
# 9    22. 0
# Name: Killed, dtype: object

# %% [markdown]
# There are embedded spaces which will need to be removed
#
# What other issues are there?

# %%
# Look for values that are not at least one digit followed by ". 0"
data.loc[~ data.Killed.str.match(r"^\d+\. 0$", na = True, as_indexer = True),"Killed"].head(20)
# Out:
# 40      158. 999999
# 41       31. 999999
# 42        3. 999999
# 43       64. 999999
# 44       15. 999999
# 46        9. 999999
# 49       17. 999999
# 50       22. 999999
# 51       29. 999999
# 52       10. 999999
# 54       32. 999999
# 55    39999. 999999
# 56      999. 999999
# 57        9. 999999
# 58       47. 999999
# 59       42. 999999
# 60       14. 999999
# 62       15. 999999
# 63       29. 999999
# 64       52. 999999
# Name: Killed, dtype: object

# %% [markdown]
# Several records are formatted "nnn. 999999", this could be the integer nnn with some extraneous data at the end, or it could be the integer nnn+1 represented as a floating point with a rounding error.
#
# Anything else?

# %%
# Look for values that are not at least one digit followed by either ". 0" or ". 999999"
data.loc[~ data.Killed.str.match(r"\d+\. (?:0|999999)$", na = True, as_indexer = True),"Killed"].head(20)
# Out:
# 300       3. 000001
# 301      27. 000001
# 303      27. 000001
# 304      68. 000001
# 305       1. 000001
# 306      10. 000001
# 308      30. 000001
# 309      80. 000001
# 310      56. 000001
# 311       8. 000001
# 313      30. 000001
# 314       4. 000001
# 316      17. 000001
# 317       4. 000001
# 318    1188. 000001
# 319      40. 000001
# 320      16. 000001
# 321      50. 000001
# 324      59. 000001
# 325      38. 000001
# Name: Killed, dtype: object

# %% [markdown]
# A few records in the format "nnn. 000001" - filter these out as well

# %%
# Look for values that are not at least one digit followed by one of ". 0", ". 999999", ". 000001"
data[~ data.Killed.str.match(r"\d+\. (?:0|999999|000001)$", na = True, as_indexer = True)].head()
# Out:
# Empty DataFrame
# Columns: [Start, End, Country, Location, Type, Sub_Type, Names, Killed, Affected, Cost, ID]
# Index: []

# %% [markdown]
# Nothing else ... so the only values after the '. ' are 0, 000001, and 999999. It looks like the 000001 and 999999 are rounding errors, so handle these by rounding the numbers after removing the space.
#
# There are two things to do to convert the Killed column to integer
# 1. Remove the extra spaces
# 2. Round the numbers to remove the .999999 or .000001

# %%
# Remove the spaces in the Killed column, change column datatype to numeric and round to an integer
data["Killed"] = pd.to_numeric(data.Killed.str.replace(" ","")).round()
data.head(10)
# Out:
#        Start        End   Country                       Location  \
# 0 1965-06-10 1965-06-10     Japan                            NaN
# 1 2004-09-08 2004-09-08   Grenada                            NaN
# 2 1995-03-15 1995-03-15    Russia   Kalmoukie:Daghestan (Mer ...
# 3 1983-02-01 1983-02-28      Cuba   Santiago de Cuba:Pinar d ...
# 4 1983-01-01 1983-12-31     Nepal                            NaN
# 5 1996-07-26 1996-07-26    Russia                     Volgorgrad
# 6 2003-06-19 2003-06-19    Turkey                        Kayseri
# 7 2003-02-16 2003-02-22  Pakistan    Baluchistan:Sindh:North ...
# 8 1986-08-01 1986-08-31  Honduras  Northeast Honduras/Mosqui ...
# 9 2007-10-13 2007-10-13  Colombia            Near Suarez (Cauca)
#
#                      Type          Sub_Type                  Names  Killed  \
# 0                   Storm  Tropical cyclone                  Dinah    61.0
# 1                   Storm  Tropical cyclone                   Ivan    39.0
# 2      Transport Accident             Water                    NaN    52.0
# 3                   Flood               NaN                    NaN    15.0
# 4       Mass movement wet         Landslide                    NaN    21.0
# 5     Industrial Accident          Gas Leak           Oil refinery     NaN
# 6  Miscellaneous accident         Explosion  Dormitory of a school    10.0
# 7                   Storm               NaN                    NaN    51.0
# 8                   Flood               NaN                    NaN     NaN
# 9     Industrial Accident          Collapse              Cold mine    22.0
#
#    Affected   Cost         ID
# 0   30000.0    NaN  1965-0036
# 1   60000.0  889.0  2004-0462
# 2       NaN    NaN  1995-0362
# 3  164575.0   60.0  1983-0042
# 4       NaN    NaN  1983-0526
# 5       NaN    NaN  1996-0209
# 6      13.0    NaN  2003-0296
# 7    2557.0    NaN  2003-0086
# 8   30000.0    NaN  1986-0093
# 9      24.0    NaN  2007-0500

# %% [markdown]
# #### Set the "Affected" Column Datatype to Integer
#
# It looks like all Affected attribute values are in nnnn.0 format. Are there any in another format?

# %%
# Look for any values that are not at least one digit followed by ".0"
data[~ data.Affected.str.match(r"^\d+\.?0?$", na=True, as_indexer=True)].head()
# Out:
# Empty DataFrame
# Columns: [Start, End, Country, Location, Type, Sub_Type, Names, Killed, Affected, Cost, ID]
# Index: []

# %% [markdown]
# No - so convert the column to numeric

# %%
# Change the NaN values in the Affected column to -999 and change column datatype to integer
data["Affected"] = pd.to_numeric(data.Affected)
data.head(10)
# Out:
#        Start        End   Country                       Location  \
# 0 1965-06-10 1965-06-10     Japan                            NaN
# 1 2004-09-08 2004-09-08   Grenada                            NaN
# 2 1995-03-15 1995-03-15    Russia   Kalmoukie:Daghestan (Mer ...
# 3 1983-02-01 1983-02-28      Cuba   Santiago de Cuba:Pinar d ...
# 4 1983-01-01 1983-12-31     Nepal                            NaN
# 5 1996-07-26 1996-07-26    Russia                     Volgorgrad
# 6 2003-06-19 2003-06-19    Turkey                        Kayseri
# 7 2003-02-16 2003-02-22  Pakistan    Baluchistan:Sindh:North ...
# 8 1986-08-01 1986-08-31  Honduras  Northeast Honduras/Mosqui ...
# 9 2007-10-13 2007-10-13  Colombia            Near Suarez (Cauca)
#
#                      Type          Sub_Type                  Names  Killed  \
# 0                   Storm  Tropical cyclone                  Dinah    61.0
# 1                   Storm  Tropical cyclone                   Ivan    39.0
# 2      Transport Accident             Water                    NaN    52.0
# 3                   Flood               NaN                    NaN    15.0
# 4       Mass movement wet         Landslide                    NaN    21.0
# 5     Industrial Accident          Gas Leak           Oil refinery     NaN
# 6  Miscellaneous accident         Explosion  Dormitory of a school    10.0
# 7                   Storm               NaN                    NaN    51.0
# 8                   Flood               NaN                    NaN     NaN
# 9     Industrial Accident          Collapse              Cold mine    22.0
#
#    Affected   Cost         ID
# 0   30000.0    NaN  1965-0036
# 1   60000.0  889.0  2004-0462
# 2       NaN    NaN  1995-0362
# 3  164575.0   60.0  1983-0042
# 4       NaN    NaN  1983-0526
# 5       NaN    NaN  1996-0209
# 6      13.0    NaN  2003-0296
# 7    2557.0    NaN  2003-0086
# 8   30000.0    NaN  1986-0093
# 9      24.0    NaN  2007-0500

# %% [markdown]
# ### Step 7: Set the "Cost" Column Datatype to Float
#
# No data issues were found with the Cost column - set it to float

# %%
# Change the Cost column datatype to float
data["Cost"] = pd.to_numeric(data.Cost)
data.head(10)
# Out:
#        Start        End   Country                       Location  \
# 0 1965-06-10 1965-06-10     Japan                            NaN
# 1 2004-09-08 2004-09-08   Grenada                            NaN
# 2 1995-03-15 1995-03-15    Russia   Kalmoukie:Daghestan (Mer ...
# 3 1983-02-01 1983-02-28      Cuba   Santiago de Cuba:Pinar d ...
# 4 1983-01-01 1983-12-31     Nepal                            NaN
# 5 1996-07-26 1996-07-26    Russia                     Volgorgrad
# 6 2003-06-19 2003-06-19    Turkey                        Kayseri
# 7 2003-02-16 2003-02-22  Pakistan    Baluchistan:Sindh:North ...
# 8 1986-08-01 1986-08-31  Honduras  Northeast Honduras/Mosqui ...
# 9 2007-10-13 2007-10-13  Colombia            Near Suarez (Cauca)
#
#                      Type          Sub_Type                  Names  Killed  \
# 0                   Storm  Tropical cyclone                  Dinah    61.0
# 1                   Storm  Tropical cyclone                   Ivan    39.0
# 2      Transport Accident             Water                    NaN    52.0
# 3                   Flood               NaN                    NaN    15.0
# 4       Mass movement wet         Landslide                    NaN    21.0
# 5     Industrial Accident          Gas Leak           Oil refinery     NaN
# 6  Miscellaneous accident         Explosion  Dormitory of a school    10.0
# 7                   Storm               NaN                    NaN    51.0
# 8                   Flood               NaN                    NaN     NaN
# 9     Industrial Accident          Collapse              Cold mine    22.0
#
#    Affected   Cost         ID
# 0   30000.0    NaN  1965-0036
# 1   60000.0  889.0  2004-0462
# 2       NaN    NaN  1995-0362
# 3  164575.0   60.0  1983-0042
# 4       NaN    NaN  1983-0526
# 5       NaN    NaN  1996-0209
# 6      13.0    NaN  2003-0296
# 7    2557.0    NaN  2003-0086
# 8   30000.0    NaN  1986-0093
# 9      24.0    NaN  2007-0500

# %% [markdown]
# ### Check All Columns are Correct Data Type

# %%
# Check the data types
data.dtypes
# Out:
# Start       datetime64[ns]
# End         datetime64[ns]
# Country             object
# Location            object
# Type                object
# Sub_Type            object
# Names               object
# Killed             float64
# Affected           float64
# Cost               float64
# ID                  object
# dtype: object

# %%
# Describe the non-numeric columns
data[["Start","End","Country","Location","Type","Sub_Type","Names","ID"]].describe()
# Out:
#                       Start                  End Country Location  \
# count                 14350                14350   14350    12458
# unique                 7656                 7719     228    10530
# top     2006-01-01 00:00:00  1983-12-31 00:00:00   China    North
# freq                     30                   39    1042       59
# first   1900-01-01 00:00:00  1900-01-13 00:00:00     NaN      NaN
# last    2008-12-31 00:00:00  2009-12-31 00:00:00     NaN      NaN
#
#                       Type Sub_Type    Names         ID
# count                14350    12515     4558      14350
# unique                  18       46     2226      13694
# top     Transport Accident     Road  Cholera  2005-0713
# freq                  3367     1565      287         21
# first                  NaN      NaN      NaN        NaN
# last                   NaN      NaN      NaN        NaN

# %%
# Describe the numeric columns
data.describe()
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              Killed      Affected           Cost
# count  1.130500e+04  8.886000e+03    3027.000000
# mean   2.803424e+03  5.925691e+05     482.783997
# std    7.753896e+04  7.240150e+06    3319.931382
# min    1.000000e+00  1.000000e+00       0.003000
# 25%             NaN           NaN            NaN
# 50%             NaN           NaN            NaN
# 75%             NaN           NaN            NaN
# max    5.000000e+06  3.000000e+08  125000.000000

# %% [markdown]
# Ignore any warning message above - it appears to be a known problem with Pandas 0.18.1 (see  https://github.com/pydata/pandas/issues/13744) and happens first time this describe is run after a kernel restart

# %% [markdown]
# ## Task 3: Save Data to CSV File
#
# - Format the two integer columns so they will be stored correctly as integers in the CSV file so if the data is used by a program in a language such a R that allow null integers, it will correctly read this as an integer.
#  *Note: the Pandas to_csv method does allow floats to be formatted without the decimal places, but the same formatting is used for all float columns and so results in the rounding of "real" floating point numbers.*
#
# - Write the formatted data frame to a CSV file; by default fields containing commas will be enclosed in quotes, so they should be read correctly if the file is loaded as a CSV file.

# %%
# Make a copy of the data frame
data_formatted = data.copy()
# Format the Killed column 
data_formatted["Killed"] = data_formatted["Killed"].map(lambda x: '%1.0f' % x, na_action="ignore")
# Format the Affected column
data_formatted["Affected"] = data_formatted["Affected"].map(lambda x: '%1.0f' % x, na_action="ignore")
# Write the formatted data frame to a CSV file
data_formatted.to_csv("XXXXXXXX_parsed_data.csv", index=False)
